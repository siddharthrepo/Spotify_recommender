# %%
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
sns.set()

# %%
data = pd.read_csv("tracks.csv")
data.head(10)
# Out:
#                        id                                 name  popularity
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6  \
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
# 5  0BRXJHRNGQ3W4v9frnSfhu                            Ave Maria           0
# 6  0Dd9ImXtAtGwsmsAD69KZT                       La Butte Rouge           0
# 7  0IA0Hju8CAgYfV1hwhidBH                              La Java           0
# 8  0IgI1UCz84pYeVetnl1lGP                   Old Fashioned Girl           0
# 9  0JV4iqw2lSKJaHBQZ0e5zK        Martín Fierro - Remasterizado           0
#
#    duration_ms  explicit              artists                  id_artists
# ...

# %%
data['year'] = data['release_date'].apply(lambda x:x.split('-')[0])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   duration_ms       586672 non-null  int64
#  4   explicit          586672 non-null  int64
#  5   artists           586672 non-null  object
#  6   id_artists        586672 non-null  object
#  7   release_date      586672 non-null  object
#  8   danceability      586672 non-null  float64
#  9   energy            586672 non-null  float64
#  10  key               586672 non-null  int64
#  11  loudness          586672 non-null  float64
#  12  mode              586672 non-null  int64
#  13  speechiness       586672 non-null  float64
#  14  acousticness      586672 non-null  float64
#  15  instrumentalness  586672 non-null  float64
# ...

# %%
data.isnull().sum()
# Out:
# id                   0
# name                71
# popularity           0
# duration_ms          0
# explicit             0
# artists              0
# id_artists           0
# release_date         0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# time_signature       0
# year                 0
# dtype: int64

# %%
df = data.drop(columns=['id' ,'name' , 'artists' , 'release_date' ,'year' , 'id_artists'])
df.fillna(0)
df.corr()
# Out:
#                   popularity  duration_ms  explicit  danceability    energy
# popularity          1.000000     0.027681  0.211758      0.187000  0.302315  \
# duration_ms         0.027681     1.000000 -0.016747     -0.120371  0.024825
# explicit            0.211758    -0.016747  1.000000      0.150229  0.123076
# danceability        0.187000    -0.120371  0.150229      1.000000  0.241563
# energy              0.302315     0.024825  0.123076      0.241563  1.000000
# key                 0.015299     0.004626  0.010932      0.018824  0.036294
# loudness            0.327028     0.000337  0.134603      0.251436  0.764735
# mode               -0.033655    -0.027610 -0.051754     -0.044719 -0.065246
# speechiness        -0.047357    -0.125771  0.102258      0.199310 -0.053506
# acousticness       -0.370882    -0.064434 -0.149018     -0.242951 -0.715412
# instrumentalness   -0.236487     0.069278 -0.067520     -0.225900 -0.195839
# ...

# %%
df
# Out:
#         popularity  duration_ms  explicit  danceability  energy  key
# 0                6       126903         0         0.645  0.4450    0  \
# 1                0        98200         0         0.695  0.2630    0
# 2                0       181640         0         0.434  0.1770    1
# 3                0       176907         0         0.321  0.0946    7
# 4                0       163080         0         0.402  0.1580    3
# ...            ...          ...       ...           ...     ...  ...
# 586667          50       258267         0         0.560  0.5180    0
# 586668          72       153293         0         0.765  0.6630    0
# 586669          70       187601         0         0.535  0.3140    7
# 586670          58       142003         0         0.696  0.6150   10
# 586671          38       214360         0         0.686  0.7230    6
#
#         loudness  mode  speechiness  acousticness  instrumentalness  liveness
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
datatypes = ['int16' , 'int32' , 'int64' ,'float16' ,'float32' ,'float64']
normalization = data.select_dtypes(include=datatypes)
for col in normalization.columns:
    MinMaxScaler(col)


# x` = (x- min(x)) / max(x) -min(x)
# since the data might lie far away from each other we normalize it

# %%
from sklearn.cluster import KMeans
# kmeans is unsupervised 
kmeans = KMeans(n_clusters=10)
features = kmeans.fit_predict(normalization)
data['features'] = features
MinMaxScaler(data['features'])
# data['features']
# Out:
# C:\Users\siddh\AppData\Roaming\Python\Python311\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# MinMaxScaler(feature_range=0         8
# 1         8
# 2         0
# 3         0
# 4         0
#          ..
# 586667    2
# 586668    0
# 586669    0
# 586670    0
# 586671    7
# Name: features, Length: 586672, dtype: int32)

# %%
class Spotify_Recommendation():
    def __init__(self , dataset):
        self.dataset = dataset
    
    def recommend(self , songs , amount=0):
        distance = []
        song = self.dataset[(self.dataset.name.str.lower() == songs.lower())].head(1).values[0]
        rec = self.dataset[self.dataset.name.str.lower() != songs.lower()]
        for songs in tqdm(rec.values):
            d = 0
            for col in np.arange(len(rec.columns)):
                if not col in [1,6,12,14,18]:
                    d = d + np.absolute(float(len(str(song[col]))) - float(len(str(songs[col]))))
            distance.append(d)

        rec['distance'] = distance
        rec = rec.sort_values('distance')
        columns = ['artists' , 'name' ,'energy']
        return rec[columns][:amount]
        # return song
        # return rec['distance']
        # return rec

# %%
recommendations = Spotify_Recommendation(data)
recommendations.recommend("slow" , 10)
# Out:
# 100%|██████████| 586669/586669 [00:15<00:00, 38880.33it/s]
# C:\Users\siddh\AppData\Local\Temp\ipykernel_9492\130537791.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rec['distance'] = distance
#                   artists                           name  energy
# 555996  ['Sound Horizon']                     恋人を射ち堕とした日   0.829
# 355724  ['Faith No More']                       Helpless   0.739
# 351067  ['Vetusta Morla']              Boca en la Tierra   0.726
# 167519  ['Pet Shop Boys']       Shopping - 2001 Remaster   0.968
# 568440  ['Mauro Picotto']          Proximus - Radio Edit   0.883
# 533989  ['Mnaga A Zdorp']                   Byla 1 holka   0.764
# 322106  ['Halldor Waren']                  Sofa Urtuborn   0.335
# ...

# %%
recommendations.recommend("rock" , 10)
# Out:
# 100%|██████████| 586669/586669 [00:15<00:00, 37800.27it/s]
# C:\Users\siddh\AppData\Local\Temp\ipykernel_9492\130537791.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rec['distance'] = distance
#                                                   artists
# 25144   ['Kenneth Nelson', 'Alonzo Bosan', 'Maurice El...  \
# 162499  ['Veikko Tuomi', 'Annikki Tähti', 'Eugen Malms...
# 164818  ['Liisa Lääveri', 'Eveliina Pokela', 'Matti Ko...
# 353177  ['Frankie Laine', 'Paul Weston And His Orchest...
# 20028   ['Narciso Parigi con Orchestra Francesco Ferra...
# 428254  ['Claudionor Germano', 'Orquestra Nelson Ferre...
# 265754  ['Richard Rodgers', 'Jack Cassidy', 'Lehman En...
# 160708  ['Veikko Tuomi', 'Annikki Tähti', 'Eugen Malms...
# ...
